# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a > b:
        return a
    elif b > a:
        return b

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.089s
#
# OK

# %%
greater(10,8)
# Out:
# 10

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(list):
    sorted_list = sorted(list)
    return sorted_list[-1]

# %%
list_1 = [2, 4, 67, 92, 45]

greatest(list_1)
# Out:
# 92

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.120s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
    tot = 0
    for i in lst:
        tot += i
    return tot

# %%
list_ex = [2, 8, 90, 32, -40]

sum_all(list_ex)
# Out:
# 92

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.078s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
    tot = 1
    for i in lst:
        tot *= i
    return tot

# %%
list_ex = [2, 4, 10]

mult_all(list_ex)
# Out:
# 80

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.073s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper="*"):
    result = 0 if oper == "+" else 1

    for i in arr:
        if oper == "+":
            result += i
        else:
            result *= i

    return result

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.082s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    result = 1
    for x in range(1, n + 1):
        result *= x
    return result

# %%
factorial(5)
# Out:
# 120

# %%
#factorial formula
#n! = n * ( n - 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.079s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):
    result = set(lst_un)
    result = list(result)
    return result

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.084s
#
# OK

# %%
list_a = [1, 22, 31, 50, 44, 22, 50]

# %%
unique(list_a)
# Out:
# [1, 44, 50, 22, 31]

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    freq = {} 
    for item in arr:
        if item in freq:
            freq[item] += 1
        else:
            freq[item] = 1
    max_freq = 0
    mode = None
    for key, value in freq.items():
        if value > max_freq:
            max_freq = value
            mode = key

    return mode

# %%
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.099s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def st_dev(list_sd):
    # Step 1: compute length (n)
    n = 0
    for _ in list_sd:
        n += 1

    # Step 2: compute mean
    total = 0
    for x in list_sd:
        total += x
    mean = total / n

    # Step 3: compute squared deviations
    squared_diff_sum = 0
    for x in list_sd:
        diff = x - mean
        squared_diff_sum += diff * diff

    # Step 4: variance
    variance = squared_diff_sum / (n-1)

    # Step 5: standard deviation (square root)
    std = variance ** 0.5

    return std

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.088s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    check = set()

    for l in string.lower():
        if l in alphabet:
            check.add(l)

    return len(check) == len(alphabet)

# %%
test_1 = "The quick brown fox jumps over the lazy dog."

pangram(test_1)
# Out:
# True

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.040s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    words = []
    current = ""
    for ch in string:
        if ch == ",":
            words.append(current)
            current = ""
        else:
            current += ch
    words.append(current)
    words = sorted(words)
    result = ""
    for i in range(len(words)):
        result += words[i]
        if i != len(words) - 1:
            result += ","

    return result

# %%
comma_list = sort_alpha("cat, dog, cow, horse, shark")

print(comma_list)
# Out:
#  cow, dog, horse, shark,cat

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.093s
#
# OK

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
    if len(password) < 8:
        return False

    alphabet = "abcdefghijklmnopqrstuvwxyz"
    digits = "0123456789"
    special_chars = "!@#$%^&*-_+=<>?/|:;,."

    has_lower = False
    has_upper = False
    has_digit = False
    has_special = False

    for ch in password:
        if ch in alphabet:
            has_lower = True
        elif ch in alphabet.upper():
            has_upper = True
        elif ch in digits:
            has_digit = True
        elif ch in special_chars:
            has_special = True

    return has_lower and has_upper and has_digit and has_special

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ......F.F.F..................F.............F...F.......F.....F.............F................F.......
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, {2Tj1Zqrsx, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, zvs[tuQkjb8, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, zyT4ll]avb, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, 1yR){K)eyGP, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, [X46oGpuaB, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, R{j8qePxels0Rr, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, m4(Ft55n9)cVR, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, 8}jM1cgAcsaxT, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, uHn0s[wrl7KVinbj, the output should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "c:\Users\ferna\OneDrive\Desktop\Fernando\Ironhack\DSML\Week_1\lab-functions-en\mod\testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input_), self.output, f"For this password, {self.input_}, the output should be {self.output}")
# AssertionError: False != True : For this password, fqz3sifjqQmd(nA6, the output should be True
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.114s
#
# FAILED (failures=10)
